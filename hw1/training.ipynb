# %%
import pandas as pd
import numpy as np


df = pd.read_csv('DataScienceJobs.csv')

df
# Out:
#                                                   name          address  \
# 0         Начинающий специалист по работе с нейросетям  Санкт-Петербург
# 1                                 Junior Data Engineer  Нижний Новгород
# 2                                           ML-инженер           Москва
# 3                                       Data Scientist           Москва
# 4                            Python Developer (Junior)            Томск
# ..                                                 ...              ...
# 355  Ведущий специалист по разработке скоринговых карт      Новосибирск
# 356       Lead data scientist (Анализ цены и Trade in)           Москва
# 357                              Senior Data Scientist            Томск
# 358                            Data engineer (middle+)      Новосибирск
# 359  Автор дисциплины "Задачи NLP в машинном обучении"  Нижний Новгород
#
#              experience                                             skills  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        360 non-null    object
#  1   address     360 non-null    object
#  2   experience  360 non-null    object
#  3   skills      360 non-null    object
#  4   sal_from    360 non-null    int64
#  5   sal_to      360 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 17.0+ KB

# %%
df['address'].value_counts(normalize=True)
# Out:
# address
# Москва                0.522222
# Санкт-Петербург       0.111111
# Московская область    0.077778
# Новосибирск           0.075000
# Казань                0.041667
# Нижний Новгород       0.041667
# Екатеринбург          0.041667
# Тюмень                0.030556
# Томск                 0.027778
# Сочи                  0.022222
# Владивосток           0.005556
# Астрахань             0.002778
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#             sal_from         sal_to
# count     360.000000     360.000000
# mean   182694.444444  231416.666667
# std     70581.279109   79938.651617
# min     45000.000000   55000.000000
# 25%    120000.000000  170000.000000
# 50%    180000.000000  225000.000000
# 75%    242500.000000  290000.000000
# max    350000.000000  570000.000000

# %%
df['sal_from'].hist()
# Out:
# <Axes: >

# %%
df.groupby('experience').size().plot(kind='pie')
# Out:
# <Axes: >

# %%
df.corr()
# Out:
# <Axes: xlabel='experience', ylabel='sal_from'>

# %%
df.groupby(['address', 'experience'])['sal_from'].mean().plot.bar()
# Out:
# <Axes: xlabel='address,experience'>

# %%
df.groupby(['address', 'experience'])['sal_from'].mean().unstack().plot.bar()
# Out:
# <Axes: xlabel='address'>
